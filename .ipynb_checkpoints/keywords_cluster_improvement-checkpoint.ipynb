# %% [markdown]
# ### 1. GOAL
# The goal of this task is to cluster keywords semantically with improvement in text cleansing. The data in previous clustering work still contains many irrelevant words which need to be removed to get resonable cluster result.
#
# ### 2. DATA
# The data is from KW Clusters file https://docs.google.com/spreadsheets/d/1pDgWNNaEJqc7oNA8khVheK9uLX7Q6Bu-5L5BxBUoBJs/edit#gid=0 we use only the keywords column
#
# ### 3. TECHNIQUE SUMMARY
#     3.1 Load data
#     3.2 Tokenize and clean data
#     3.3 Train word2vec on custom corpus
#     3.4 Cluster keywords using K-Means

# %% [markdown]
# ### 3.1 Load Data

# %%
# %matplotlib inline

import nltk.data
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import string

from gensim.models import Word2Vec
from gensim.models.phrases import Phraser, Phrases
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

from sklearn.cluster import KMeans
from sklearn.neighbors import KDTree

import pandas as pd
import numpy as np
from statistics import mean

import os
import re
import logging
import time
import sys
import multiprocessing
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from itertools import cycle

# %%
# get keywords column from KW Clusters excel file
df = pd.read_excel('kw_clusters.xlsx', sheetname='All')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
df['keywords']
# Out:
# 0      nectar  website | nectar  mattress store | nec...
# 1      nectar website  | bb website  | brooklyn beddi...
# 2      friend  | friend  referred | friend s | friend...
# 3      leesa  mattress | googled leesa  | leesa  and ...
# 4      yelp  | yelp , and then visited your new york ...
# 5      mattress stores  | mattress stores  nyc | bb s...
# 6      mom  group long island city | my mom  | mom  f...
# 7      mom group  long island city | facebook group  ...
# 8                            mom group long  island city
# 9                            mom group long island  city
# 10     mom group long island city  | google "new york...
# 11                                          neighborhood
# 12     casper  nyc | leesa and casper  showroom | mat...
# 13     where  to buy saatva bed | where  to try saatv...
# 14     where to buy  saatva bed | where can i buy  sa...
# 15     where to buy saatva  bed | where to try saatva...
# 16     googled brooklyn  bedding | brooklyn  bedding ...
# 17     winkbeds  | winkbeds  website | winkbeds  test...
# 18     purple  mattress | purple  | googling for lees...
# 19     walk  by | walk  in | walk ed by | walk ed in ...
# 20                                          winked  beds
# 21     helix  website | helix  reviews | helix  dusk ...
# 22     wink beds | wink ed beds | nyc wink  bed | win...
# 23     husband  | husband  googled | husband  pooked ...
# 24     brooklying  bedding showroom | brooklying  bed...
# 25     son  | comparison  mattress | comparison  try ...
# 26                       returning  customer | returning
# 27     returning customer  | saatva customer  service...
# 28                                      saatvz  mattress
# 29     googled test  online beds new york | winkbed t...
#                              ...
# 258    fir m mattress | matress matressfir m | fir m ...
# 259        coworker  recommended | co worker  | coworker
# 260    see ing | how can i see  the purple mattress i...
# 261    google maps - addresss  | try i fernet mattres...
# 262    tuck .com | tuck .com winkbed | tuck  sleep re...
# 263    just  walking | google adjust able bed nyc | j...
# 264    google:  purple mattress nyc | google:  purple...
# 265    consumer rep orts | bear rep resentitive | cas...
# 266    bear represent itive | casper store represent ...
# 267         mattress location s | googled store location
# 268    yelp, and then visited your  new york store an...
# 269    air weave partner | air weave website | air we...
# 270    airweave  partner | airweave  website | airwea...
# 271    friend referr ed | referr al | referr ed | bro...
# 272        google saatvia  | online mattress via  google
# 273                            buying  online mattresses
# 274                              referral justin  samson
# 275                               referral justin samson
# 276                                    brooklyn bedding1
# 277                                     mimi  refered me
# 278                                     mimi refered  me
# 279                             google+  | google+ maps+
# 280                                            referral+
# 281                                    try tuten  needle
# 282                                         google+maps+
# 283                                            wales  by
# 284                 where to buy the best hard  mattress
# 285                                               tamara
# 286                                     scosis  mattress
# 287                                google talalay  latex
# Name: keywords, Length: 288, dtype: object

# %%
# convert the collective keywords with '|' delimiter to columns
# then transpose it to rows

df_keywords_split = df['keywords'].str.split("|",expand=True)

# %%
df_keywords_split
# Out:
#                                                     0   \
# 0                                     nectar  website
# 1                                     nectar website
# 2                                             friend
# 3                                     leesa  mattress
# 4                                               yelp
# 5                                    mattress stores
# 6                         mom  group long island city
# 7                         mom group  long island city
# 8                          mom group long  island city
# 9                          mom group long island  city
# 10                        mom group long island city
# 11                                        neighborhood
# 12                                        casper  nyc
# 13                           where  to buy saatva bed
# 14                           where to buy  saatva bed
# 15                           where to buy saatva  bed
# 16                          googled brooklyn  bedding
# 17                                          winkbeds
# 18                                   purple  mattress
# 19                                           walk  by
# 20                                        winked  beds
# 21                                     helix  website
# 22                                          wink beds
# 23                                           husband
# 24                       brooklying  bedding showroom
# 25                                               son
# 26                                returning  customer
# 27                                returning customer
# 28                                    saatvz  mattress
# 29                 googled test  online beds new york
# ..                                                 ...
# 258                                    fir m mattress
# 259                             coworker  recommended
# 260                                           see ing
# 261                           google maps - addresss
# 262                                         tuck .com
# 263                                     just  walking
# 264                      google:  purple mattress nyc
# 265                                 consumer rep orts
# 266                              bear represent itive
# 267                               mattress location s
# 268  yelp, and then visited your  new york store an...
# 269                                 air weave partner
# 270                                 airweave  partner
# 271                                  friend referr ed
# 272                                   google saatvia
# 273                          buying  online mattresses
# 274                            referral justin  samson
# 275                             referral justin samson
# 276                                  brooklyn bedding1
# 277                                   mimi  refered me
# 278                                   mimi refered  me
# 279                                          google+
# 280                                          referral+
# 281                                  try tuten  needle
# 282                                       google+maps+
# 283                                          wales  by
# 284               where to buy the best hard  mattress
# 285                                             tamara
# 286                                   scosis  mattress
# 287                              google talalay  latex
#
#                                                     1   \
# 0                              nectar  mattress store
# 1                                         bb website
# 2                                    friend  referred
# 3                                      googled leesa
# 4     yelp , and then visited your new york store a...
# 5                                mattress stores  nyc
# 6                                             my mom
# 7                                     facebook group
# 8                                                 None
# 9                                                 None
# 10                  google "new york city  showrooms"
# 11                                                None
# 12                         leesa and casper  showroom
# 13                               where  to try saatva
# 14                            where can i buy  saatva
# 15                               where to try saatva
# 16                          brooklyn  bedding website
# 17                                  winkbeds  website
# 18                                            purple
# 19                                           walk  in
# 20                                                None
# 21                                     helix  reviews
# 22                                       wink ed beds
# 23                                   husband  googled
# 24                                 brooklying  bedding
# 25                               comparison  mattress
# 26                                           returning
# 27                           saatva customer  service
# 28                                                None
# 29                          winkbed test ing in store
# ..                                                 ...
# 258                              matress matressfir m
# 259                                        co worker
# 260   how can i see  the purple mattress in the rea...
# 261                         try i fernet mattresss es
# 262                                 tuck .com winkbed
# 263                        google adjust able bed nyc
# 264                          google:  purple mattress
# 265                              bear rep resentitive
# 266                      casper store represent ative
# 267                             googled store location
# 268                                         your  mom
# 269                                 air weave website
# 270                                 airweave  website
# 271                                         referr al
# 272                        online mattress via  google
# 273                                               None
# 274                                               None
# 275                                               None
# 276                                               None
# 277                                               None
# 278                                               None
# 279                                      google+ maps+
# 280                                               None
# 281                                               None
# 282                                               None
# 283                                               None
# 284                                               None
# 285                                               None
# 286                                               None
# 287                                               None
#
#                                                2   \
# 0                                        nectar
# 1                      brooklyn bedding website
# 2                                       friend s
# 3                     leesa  and casper showroom
# 4                             yelp  mattress bed
# 5                                     bb stores
# 6      mom  facebook group upper east side mom s
# 7       mom facebook group  upper east side moms
# 8                                            None
# 9                                            None
# 10                             beds in the city
# 11                                           None
# 12                              mattress casper
# 13              where  can i try saatva mattress
# 14                                  walking buy
# 15              where can i try saatva  mattress
# 16                      brooklyn  bedding aurora
# 17                             winkbeds  testing
# 18       googling for leesa & purple  show rooms
# 19                                    walk ed by
# 20                                           None
# 21                                   helix  dusk
# 22                                 nyc wink  bed
# 23                    husband  pooked fir saatva
# 24                                           None
# 25                           comparison  try out
# 26                                           None
# 27                            previous customer
# 28                                           None
# 29                    places to test  mattresses
# ..                                            ...
# 258                                        fir m
# 259                                      coworker
# 260                                      hasee b
# 261                                    matresss
# 262                           tuck  sleep review
# 263                 just  passed by the showroom
# 264                            google:  mattress
# 265                 casper store rep resentative
# 266                             mother sent  love
# 267                                          None
# 268   brooklyn bedding website link to our  store
# 269                        air weave dealer site
# 270                        airweave  dealer site
# 271                                    referr ed
# 272                                          None
# 273                                          None
# 274                                          None
# 275                                          None
# 276                                          None
# 277                                          None
# 278                                          None
# 279                                          None
# 280                                          None
# 281                                          None
# 282                                          None
# 283                                          None
# 284                                          None
# 285                                          None
# 286                                          None
# 287                                          None
#
#                                           3   \
# 0                           googled nectar
# 1                            helix website
# 2                   friend  - word of mouth
# 3                            leesa  mattris
# 4                              yelp  casper
# 5                     best mattress stores
# 6                      mom s group facebook
# 7                       moms group  facebook
# 8                                       None
# 9                                       None
# 10    google mattress stores new york city
# 11                                      None
# 12                         casper  mattress
# 13                     where  to try nectar
# 14                buy ing online mattresses
# 15                  saatva  online retailer
# 16               brooklyn  bedding mattress
# 17                           winkbeds  site
# 18                           purple  casper
# 19                               walk ed in
# 20                                      None
# 21                          referral helix
# 22                        wink beds website
# 23             husband  heard about showroom
# 24                                      None
# 25                      comparison , try on
# 26                                      None
# 27                       pervious customer
# 28                                      None
# 29                        winkbeds test ing
# ..                                       ...
# 258                           fir m matress
# 259                                     None
# 260       where i could see  saatva mattress
# 261                      cooling mattresss
# 262                            tuck  review
# 263                  referral just in samson
# 264                   google:  try in store
# 265                                 rep eat
# 266                                     None
# 267                                     None
# 268                                     None
# 269                          air weave firm
# 270                          airweave  firm
# 271              brooklyn bedding referr al
# 272                                     None
# 273                                     None
# 274                                     None
# 275                                     None
# 276                                     None
# 277                                     None
# 278                                     None
# 279                                     None
# 280                                     None
# 281                                     None
# 282                                     None
# 283                                     None
# 284                                     None
# 285                                     None
# 286                                     None
# 287                                     None
#
#                                                     4   \
# 0                                    nectar  showroom
# 1                                   winkbeds website
# 2                                    friend  referral
# 3             googling for leesa  & purple show rooms
# 4                                               yelp
# 5                     mattress stores  on google maps
# 6                                           your mom
# 7                                                 None
# 8                                                 None
# 9                                                 None
# 10                              nectar new york city
# 11                                                None
# 12                                   casper  showroom
# 13              where  to try mattresses, google maps
# 14                where to buy  the best hard mattress
# 15                                     saatva , store
# 16                                  brooklyn  bedding
# 17                                          winkbeds
# 18                              purple  nectar casper
# 19                                        walk ing by
# 20                                                None
# 21                                    helix  showroom
# 22                                  googling wink bed
# 23                                                None
# 24                                                None
# 25                        mattress comparison  caspar
# 26                                                None
# 27                     winkbed customer  service team
# 28                                                None
# 29    google test  a mattress brooklyn bedding webs...
# ..                                                 ...
# 258                                    airweave fir m
# 259                                               None
# 260                                               None
# 261                               try xxxx mattresss
# 262                                   satvaa tuck .com
# 263                                               None
# 264              google:  mattress showrooms manhattan
# 265                                        leesa rep
# 266                                               None
# 267                                               None
# 268                                               None
# 269                                         air weave
# 270                                         airweave
# 271                        tufts and needle referr ed
# 272                                               None
# 273                                               None
# 274                                               None
# 275                                               None
# 276                                               None
# 277                                               None
# 278                                               None
# 279                                               None
# 280                                               None
# 281                                               None
# 282                                               None
# 283                                               None
# 284                                               None
# 285                                               None
# 286                                               None
# 287                                               None
#
#                                         5   \
# 0                             nectar  try
# 1                        winkbed website
# 2                              boyfriend
# 3                  reddit- leesa  reviews
# 4                 mattress stores (yelp )
# 5                          nectar stores
# 6                                      mom
# 7                                     None
# 8                                     None
# 9                                     None
# 10         saatva mattress new york city
# 11                                    None
# 12                                casper
# 13       where  can i try online mattress
# 14                                    None
# 15                   saatva  mattress try
# 16    showrooms in nyc, brooklyn  bedding
# 17                       google winkbeds
# 18              google "purple  showroom"
# 19                           street walk
# 20                                    None
# 21                                   helix
# 22              wink bed testing in store
# 23                                    None
# 24                                    None
# 25                        my son  told me
# 26                                    None
# 27                  bear customer  service
# 28                                    None
# 29                    test  foam mattress
# ..                                     ...
# 258                   saatva luxury fir m
# 259                                   None
# 260                                   None
# 261                                  sss
# 262                                   None
# 263                                   None
# 264                                   None
# 265                      consumer rep orts
# 266                                   None
# 267                                   None
# 268                                   None
# 269                    air weave mattress
# 270                    airweave  mattress
# 271               family member referr al
# 272                                   None
# 273                                   None
# 274                                   None
# 275                                   None
# 276                                   None
# 277                                   None
# 278                                   None
# 279                                   None
# 280                                   None
# 281                                   None
# 282                                   None
# 283                                   None
# 284                                   None
# 285                                   None
# 286                                   None
# 287                                   None
#
#                                        6   \
# 0                       nectar  research
# 1                       website  reviews
# 2                          friend  refer
# 3                                 leesa
# 4                  yelp  mattress stores
# 5                 online bedding stores
# 6                                    None
# 7                                    None
# 8                                    None
# 9                                    None
# 10       mattress testing new york city
# 11                                   None
# 12                       casper  try nyc
# 13       where  to try mattresses in nyc
# 14                                   None
# 15                               saatva
# 16            brooklyn  bedding referral
# 17                      winkbeds  to try
# 18                        satvaa purple
# 19                               walk by
# 20                                   None
# 21                                   None
# 22                        wink bed store
# 23                                   None
# 24                                   None
# 25                           comoarison
# 26                                   None
# 27                                   None
# 28                                   None
# 29                     test ing mattress
# ..                                    ...
# 258   medium fir m mattress for sciatica
# 259                                  None
# 260                                  None
# 261                      purple mattresss
# 262                                  None
# 263                                  None
# 264                                  None
# 265                                  None
# 266                                  None
# 267                                  None
# 268                                  None
# 269           walk in, air weave website
# 270           walk in, airweave  website
# 271                     friend referr al
# 272                                  None
# 273                                  None
# 274                                  None
# 275                                  None
# 276                                  None
# 277                                  None
# 278                                  None
# 279                                  None
# 280                                  None
# 281                                  None
# 282                                  None
# 283                                  None
# 284                                  None
# 285                                  None
# 286                                  None
# 287                                  None
#
#                                                  7   \
# 0                                 nectar  mattress
# 1     winkbed website  showed there was a showroom
# 2                         a friend  recommendation
# 3                                  leesa  showroom
# 4                               leesa mattress yelp
# 5            google mattress stores  new york city
# 6                                              None
# 7                                              None
# 8                                              None
# 9                                              None
# 10                    mattresses in new york city
# 11                                             None
# 12               i searched for "casper  showroom"
# 13                            where  to try casper
# 14                                             None
# 15                        saatva  customer service
# 16                       brooklyn  bedding locator
# 17                                         winkbeds
# 18                               showrooms purple
# 19                                     walk ing in
# 20                                             None
# 21                                             None
# 22                                    google wink
# 23                                             None
# 24                                             None
# 25                                         my son
# 26                                             None
# 27                                             None
# 28                                             None
# 29                        mattress stores test ing
# ..                                              ...
# 258                     husband pooked fir  saatva
# 259                                            None
# 260                                            None
# 261                                            None
# 262                                            None
# 263                                            None
# 264                                            None
# 265                                            None
# 266                                            None
# 267                                            None
# 268                                            None
# 269                               online air weave
# 270                               online airweave
# 271                               online referr al
# 272                                            None
# 273                                            None
# 274                                            None
# 275                                            None
# 276                                            None
# 277                                            None
# 278                                            None
# 279                                            None
# 280                                            None
# 281                                            None
# 282                                            None
# 283                                            None
# 284                                            None
# 285                                            None
# 286                                            None
# 287                                            None
#
#                                                     8   \
# 0                                where to try nectar
# 1                                     saatva website
# 2                                 referred by friend
# 3                                     leesa  mattress
# 4                                                 None
# 5                             matress stores  near me
# 6                                                 None
# 7                                                 None
# 8                                                 None
# 9                                                 None
# 10                               leesa new york city
# 11                                                None
# 12                               casper  mattress nyc
# 13                                  somewhere  online
# 14                                                None
# 15                                 looking to saatva
# 16    google test a mattress brooklyn  bedding webs...
# 17                                                None
# 18                          google nectar and purple
# 19                                           walk ing
# 20                                                None
# 21                                                None
# 22                                       try wink bed
# 23                                                None
# 24                                                None
# 25                               mattress comparison
# 26                                                None
# 27                                                None
# 28                                                None
# 29                                          car test
# ..                                                 ...
# 258                           fir m mattress show room
# 259                                               None
# 260                                               None
# 261                                               None
# 262                                               None
# 263                                               None
# 264                                               None
# 265                                               None
# 266                                               None
# 267                                               None
# 268                                               None
# 269                                 online air  weave
# 270                                 online air weave
# 271                               referr ed by friend
# 272                                               None
# 273                                               None
# 274                                               None
# 275                                               None
# 276                                               None
# 277                                               None
# 278                                               None
# 279                                               None
# 280                                               None
# 281                                               None
# 282                                               None
# 283                                               None
# 284                                               None
# 285                                               None
# 286                                               None
# 287                                               None
#
#                                               9         ...         \
# 0                             nectar  show room         ...
# 1                                winks website          ...
# 2                                       friend          ...
# 3                                leesa  website         ...
# 4                                           None        ...
# 5                      mattress stores  testing         ...
# 6                                           None        ...
# 7                                           None        ...
# 8                                           None        ...
# 9                                           None        ...
# 10               mattress stores new york city          ...
# 11                                          None        ...
# 12                      casper  mattress try ny         ...
# 13                      where  can i buy saatva         ...
# 14                                          None        ...
# 15                         saatva  trying store         ...
# 16                   brooklyn  bedding showroom         ...
# 17                                          None        ...
# 18                   purple  nector google maps         ...
# 19                         walk  in from street         ...
# 20                                          None        ...
# 21                                          None        ...
# 22                           showroom for wink          ...
# 23                                          None        ...
# 24                                          None        ...
# 25    searched for a comparison  mattress store         ...
# 26                                          None        ...
# 27                                          None        ...
# 28                                          None        ...
# 29                                test  keyword         ...
# ..                                           ...        ...
# 258                                         None        ...
# 259                                         None        ...
# 260                                         None        ...
# 261                                         None        ...
# 262                                         None        ...
# 263                                         None        ...
# 264                                         None        ...
# 265                                         None        ...
# 266                                         None        ...
# 267                                         None        ...
# 268                                         None        ...
# 269                           air weave showroom        ...
# 270                           airweave  showroom        ...
# 271                       referr ed from casper         ...
# 272                                         None        ...
# 273                                         None        ...
# 274                                         None        ...
# 275                                         None        ...
# 276                                         None        ...
# 277                                         None        ...
# 278                                         None        ...
# 279                                         None        ...
# 280                                         None        ...
# 281                                         None        ...
# 282                                         None        ...
# 283                                         None        ...
# 284                                         None        ...
# 285                                         None        ...
# 286                                         None        ...
# 287                                         None        ...
#
#                             66                         67  \
# 0              google nectar     nectar  website chatroom
# 1                         None                       None
# 2                         None                       None
# 3                         None                       None
# 4                         None                       None
# 5                         None                       None
# 6                         None                       None
# 7                         None                       None
# 8                         None                       None
# 9                         None                       None
# 10                        None                       None
# 11                        None                       None
# 12                        None                       None
# 13                        None                       None
# 14                        None                       None
# 15    google saatva  showroom              leesa saatva
# 16                        None                       None
# 17                        None                       None
# 18                        None                       None
# 19                        None                       None
# 20                        None                       None
# 21                        None                       None
# 22                        None                       None
# 23                        None                       None
# 24                        None                       None
# 25                        None                       None
# 26                        None                       None
# 27                        None                       None
# 28                        None                       None
# 29                        None                       None
# ..                         ...                        ...
# 258                       None                       None
# 259                       None                       None
# 260                       None                       None
# 261                       None                       None
# 262                       None                       None
# 263                       None                       None
# 264                       None                       None
# 265                       None                       None
# 266                       None                       None
# 267                       None                       None
# 268                       None                       None
# 269                       None                       None
# 270                       None                       None
# 271                       None                       None
# 272                       None                       None
# 273                       None                       None
# 274                       None                       None
# 275                       None                       None
# 276                       None                       None
# 277                       None                       None
# 278                       None                       None
# 279                       None                       None
# 280                       None                       None
# 281                       None                       None
# 282                       None                       None
# 283                       None                       None
# 284                       None                       None
# 285                       None                       None
# 286                       None                       None
# 287                       None                       None
#
#                       68                                    69  \
# 0                   None                                  None
# 1                   None                                  None
# 2                   None                                  None
# 3                   None                                  None
# 4                   None                                  None
# 5                   None                                  None
# 6                   None                                  None
# 7                   None                                  None
# 8                   None                                  None
# 9                   None                                  None
# 10                  None                                  None
# 11                  None                                  None
# 12                  None                                  None
# 13                  None                                  None
# 14                  None                                  None
# 15    searching saatva     where i could see saatva  mattress
# 16                  None                                  None
# 17                  None                                  None
# 18                  None                                  None
# 19                  None                                  None
# 20                  None                                  None
# 21                  None                                  None
# 22                  None                                  None
# 23                  None                                  None
# 24                  None                                  None
# 25                  None                                  None
# 26                  None                                  None
# 27                  None                                  None
# 28                  None                                  None
# 29                  None                                  None
# ..                   ...                                   ...
# 258                 None                                  None
# 259                 None                                  None
# 260                 None                                  None
# 261                 None                                  None
# 262                 None                                  None
# 263                 None                                  None
# 264                 None                                  None
# 265                 None                                  None
# 266                 None                                  None
# 267                 None                                  None
# 268                 None                                  None
# 269                 None                                  None
# 270                 None                                  None
# 271                 None                                  None
# 272                 None                                  None
# 273                 None                                  None
# 274                 None                                  None
# 275                 None                                  None
# 276                 None                                  None
# 277                 None                                  None
# 278                 None                                  None
# 279                 None                                  None
# 280                 None                                  None
# 281                 None                                  None
# 282                 None                                  None
# 283                 None                                  None
# 284                 None                                  None
# 285                 None                                  None
# 286                 None                                  None
# 287                 None                                  None
#
#                           70                 71  \
# 0                       None               None
# 1                       None               None
# 2                       None               None
# 3                       None               None
# 4                       None               None
# 5                       None               None
# 6                       None               None
# 7                       None               None
# 8                       None               None
# 9                       None               None
# 10                      None               None
# 11                      None               None
# 12                      None               None
# 13                      None               None
# 14                      None               None
# 15    saatva  search google    saatva  website
# 16                      None               None
# 17                      None               None
# 18                      None               None
# 19                      None               None
# 20                      None               None
# 21                      None               None
# 22                      None               None
# 23                      None               None
# 24                      None               None
# 25                      None               None
# 26                      None               None
# 27                      None               None
# 28                      None               None
# 29                      None               None
# ..                       ...                ...
# 258                     None               None
# 259                     None               None
# 260                     None               None
# 261                     None               None
# 262                     None               None
# 263                     None               None
# 264                     None               None
# 265                     None               None
# 266                     None               None
# 267                     None               None
# 268                     None               None
# 269                     None               None
# 270                     None               None
# 271                     None               None
# 272                     None               None
# 273                     None               None
# 274                     None               None
# 275                     None               None
# 276                     None               None
# 277                     None               None
# 278                     None               None
# 279                     None               None
# 280                     None               None
# 281                     None               None
# 282                     None               None
# 283                     None               None
# 284                     None               None
# 285                     None               None
# 286                     None               None
# 287                     None               None
#
#                                 72                                  73  \
# 0                             None                                None
# 1                             None                                None
# 2                             None                                None
# 3                             None                                None
# 4                             None                                None
# 5                             None                                None
# 6                             None                                None
# 7                             None                                None
# 8                             None                                None
# 9                             None                                None
# 10                            None                                None
# 11                            None                                None
# 12                            None                                None
# 13                            None                                None
# 14                            None                                None
# 15    how to try saatva  mattress    where i can try saatva  mattress
# 16                            None                                None
# 17                            None                                None
# 18                            None                                None
# 19                            None                                None
# 20                            None                                None
# 21                            None                                None
# 22                            None                                None
# 23                            None                                None
# 24                            None                                None
# 25                            None                                None
# 26                            None                                None
# 27                            None                                None
# 28                            None                                None
# 29                            None                                None
# ..                             ...                                 ...
# 258                           None                                None
# 259                           None                                None
# 260                           None                                None
# 261                           None                                None
# 262                           None                                None
# 263                           None                                None
# 264                           None                                None
# 265                           None                                None
# 266                           None                                None
# 267                           None                                None
# 268                           None                                None
# 269                           None                                None
# 270                           None                                None
# 271                           None                                None
# 272                           None                                None
# 273                           None                                None
# 274                           None                                None
# 275                           None                                None
# 276                           None                                None
# 277                           None                                None
# 278                           None                                None
# 279                           None                                None
# 280                           None                                None
# 281                           None                                None
# 282                           None                                None
# 283                           None                                None
# 284                           None                                None
# 285                           None                                None
# 286                           None                                None
# 287                           None                                None
#
#                  74                75
# 0              None              None
# 1              None              None
# 2              None              None
# 3              None              None
# 4              None              None
# 5              None              None
# 6              None              None
# 7              None              None
# 8              None              None
# 9              None              None
# 10             None              None
# 11             None              None
# 12             None              None
# 13             None              None
# 14             None              None
# 15    saatva  site    research saatva
# 16             None              None
# 17             None              None
# 18             None              None
# 19             None              None
# 20             None              None
# 21             None              None
# 22             None              None
# 23             None              None
# 24             None              None
# 25             None              None
# 26             None              None
# 27             None              None
# 28             None              None
# 29             None              None
# ..              ...               ...
# 258            None              None
# 259            None              None
# 260            None              None
# 261            None              None
# 262            None              None
# 263            None              None
# 264            None              None
# 265            None              None
# 266            None              None
# 267            None              None
# 268            None              None
# 269            None              None
# 270            None              None
# 271            None              None
# 272            None              None
# 273            None              None
# 274            None              None
# 275            None              None
# 276            None              None
# 277            None              None
# 278            None              None
# 279            None              None
# 280            None              None
# 281            None              None
# 282            None              None
# 283            None              None
# 284            None              None
# 285            None              None
# 286            None              None
# 287            None              None
#
# [288 rows x 76 columns]

# %%
def transpose_keywords (df):
    df_rows_transpose = list()
    for idx in range(len(df)):
        df_row_transpose = df.iloc[idx].transpose()
        df_rows_transpose.append(df_row_transpose)
    df_keywords_transpose = pd.concat(df_rows_transpose)
    df_keywords_transpose = df_keywords_transpose.dropna()
    df_keywords_transpose = df_keywords_transpose.reset_index()
    df_keywords_transpose = df_keywords_transpose.drop(columns=['index'])
    df_keywords_transpose = df_keywords_transpose.rename(columns={0:"keywords"})
    return df_keywords_transpose

# %%
df_keywords = transpose_keywords(df_keywords_split)

# %%
df_keywords
# Out:
#                                   keywords
# 0                         nectar  website
# 1                  nectar  mattress store
# 2                                 nectar
# 3                         googled nectar
# 4                        nectar  showroom
# 5                             nectar  try
# 6                        nectar  research
# 7                        nectar  mattress
# 8                    where to try nectar
# 9                       nectar  show room
# 10        google - nectar  mattress store
# 11       online "nectar  distributor page
# 12                     nectar  mattresses
# 13          nectar  brick and motar store
# 14                    online; nectar  try
# 15                  purple nectar  casper
# 16                         nectar  stores
# 17              google nectar  and purple
# 18                        nectar  matress
# 19                            nectar  vs.
# 20                         google nectar
# 21                      nectar  showrooms
# 22              google nectar  to try out
# 23                   try nectar  mattress
# 24                       nectar  in store
# 25                  nectar  new york city
# 26                                nectar
# 27                     try casper nectar
# 28                         nectar  ,ecosa
# 29                nectar  bed in new york
# ...                                    ...
# 1607                  referr ed by friend
# 1608                referr ed from casper
# 1609                   referr ed by leesa
# 1610                     sister referr al
# 1611                  referr al by friend
# 1612                      referr al helix
# 1613   friend referr al, from another wom
# 1614                   personal referr al
# 1615                              referr
# 1616                     vendor referr ed
# 1617              referr al justin samson
# 1618                            referr al+
# 1619                      google saatvia
# 1620           online mattress via  google
# 1621             buying  online mattresses
# 1622               referral justin  samson
# 1623                referral justin samson
# 1624                     brooklyn bedding1
# 1625                      mimi  refered me
# 1626                      mimi refered  me
# 1627                             google+
# 1628                         google+ maps+
# 1629                             referral+
# 1630                     try tuten  needle
# 1631                          google+maps+
# 1632                             wales  by
# 1633  where to buy the best hard  mattress
# 1634                                tamara
# 1635                      scosis  mattress
# 1636                 google talalay  latex
#
# [1637 rows x 1 columns]

# %%
# save keywords to excel file
# df_keywords.to_excel('keywords.xlsx')

# %% [markdown]
# ### 3.2 Tokenize and clean data
# We manually remove rows of irrelevant keywords, fix spelling and remove duplicates. The irrelevant keywords can be found on sheet 'irrelevant_keywords' and spelling we fix on sheet 'fix_spelling'. Keywords with no irrelevants and right spelling is on sheet 'fix_keywords'. We also add new stopwords list by finding other irrelevant words in keyword phrases manually (sheet 'stopwords_addition'). Load it again later and then add it to current stopword list.

# %%
# add new words to current stopwords list
# load new stopwords
newStopwords = pd.read_excel('keywords.xlsx', sheetname='stopwords_addition')

# %%
# convert new stopwords dataframe to list
newStopwords = newStopwords.values.tolist()

# %%
newStopwords_list = list()
for list_stopwords in newStopwords:
    newStopwords_list.extend(list_stopwords)

# %%
# add new words to current stopwords list
stop_words = stopwords.words('english')
stop_words.extend(newStopwords_list)
stop_words = list(set(stop_words))

# %%
# load fix keywords from keywords excel file
df = pd.read_excel('keywords.xlsx', sheetname='fix_keywords')

# %%
# tokenize keywords
df["tokenized_keywords"] = df['keywords'].apply(nltk.word_tokenize)

# %%
df["tokenized_keywords"]
# Out:
# 0                                       [nectar, website]
# 1                               [nectar, mattress, store]
# 2                                                [nectar]
# 3                                       [googled, nectar]
# 4                                      [nectar, showroom]
# 5                                           [nectar, try]
# 6                                      [nectar, research]
# 7                                      [nectar, mattress]
# 8                                [where, to, try, nectar]
# 9                    [google, -, nectar, mattress, store]
# 10                [online, ``, nectar, distributor, page]
# 11                                   [nectar, mattresses]
# 12                     [nectar, brick, and, motar, store]
# 13                               [online, ;, nectar, try]
# 14                               [purple, nectar, casper]
# 15                                       [nectar, stores]
# 16                          [google, nectar, and, purple]
# 17                                      [nectar, matress]
# 18                                        [nectar, vs, .]
# 19                                       [google, nectar]
# 20                                    [nectar, showrooms]
# 21                         [google, nectar, to, try, out]
# 22                                [try, nectar, mattress]
# 23                                    [nectar, in, store]
# 24                                          [nectar, nyc]
# 25                                  [try, casper, nectar]
# 26                                     [nectar, ,, ecosa]
# 27                                  [nectar, bed, in, ny]
# 28                                          [nectar, bed]
# 29                                [nectar, mattress, nyc]
#                               ...
# 1119                     [google, adjust, able, bed, nyc]
# 1120                   [google, :, purple, mattress, nyc]
# 1121                        [google, :, purple, mattress]
# 1122                                [google, :, mattress]
# 1123          [google, :, mattress, showrooms, manhattan]
# 1124                             [bear, rep, resentitive]
# 1125                    [casper, store, rep, resentative]
# 1126                                         [leesa, rep]
# 1127                                [consumer, rep, orts]
# 1128                      [casper, store, representative]
# 1129                              [mattress, location, s]
# 1130    [brooklyn, bedding, website, link, to, our, st...
# 1131                                [air, weave, partner]
# 1132                                [air, weave, website]
# 1133                           [air, weave, dealer, site]
# 1134                                   [air, weave, firm]
# 1135                                         [air, weave]
# 1136                               [air, weave, mattress]
# 1137                   [walk, in, ,, air, weave, website]
# 1138                                 [online, air, weave]
# 1139                                 [online, air, weave]
# 1140                               [air, weave, showroom]
# 1141                       [tufts, and, needle, referred]
# 1142                      [online, mattress, via, google]
# 1143                         [buying, online, mattresses]
# 1144                                 [brooklyn, bedding1]
# 1145                                 [try, tuten, needle]
# 1146          [where, to, buy, the, best, hard, mattress]
# 1147                                   [scosis, mattress]
# 1148                             [google, talalay, latex]
# Name: tokenized_keywords, Length: 1138, dtype: object

# %%
# convert dataframe to list of list
tokenized_keywords = df["tokenized_keywords"].values.tolist()

# %%
# Clean keywords
# Convert to lowercase
# Remove punctuation from each word
# Filter out remaining tokens that are not alphabetic
# Filter out tokens that are stop words
# lemmatization
def clean_text(list_tokens):
    #ps = PorterStemmer()
    word_lemma = WordNetLemmatizer()
    cleaned_tokens = list()
    for tokens in list_tokens:
        # convert to lower case
        tokens = [w.lower() for w in tokens]
        # remove punctuation from each word
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove remaining tokens that are not alphabetic
        words = [word for word in stripped if word.isalpha()]
        # filter out stop words
        words = [w for w in words if not w in stop_words]
        # stemming
        # words = [ps.stem (w) for w in words]
        # lemmatize
        # nltk.download('wordnet')
        words = [word_lemma.lemmatize (w) for w in words]
        cleaned_tokens.append(words)
    return cleaned_tokens

# %%
# apply clean_text method to the tokenized_keywords
cleaned_keywords = clean_text(tokenized_keywords)

# %%
cleaned_keywords
# Out:
# [['nectar'],
#  ['nectar', 'mattress', 'store'],
#  ['nectar'],
#  ['nectar'],
#  ['nectar', 'showroom'],
#  ['nectar', 'try'],
#  ['nectar', 'research'],
#  ['nectar', 'mattress'],
#  ['try', 'nectar'],
#  ['nectar', 'mattress', 'store'],
#  ['nectar', 'distributor'],
#  ['nectar', 'mattress'],
#  ['nectar', 'brick', 'motar', 'store'],
#  ['nectar', 'try'],
#  ['purple', 'nectar', 'casper'],
#  ['nectar', 'store'],
#  ['nectar', 'purple'],
#  ['nectar', 'matress'],
#  ['nectar'],
#  ['nectar'],
#  ['nectar', 'showroom'],
#  ['nectar', 'try'],
#  ['try', 'nectar', 'mattress'],
#  ['nectar', 'store'],
#  ['nectar', 'nyc'],
#  ['try', 'casper', 'nectar'],
#  ['nectar', 'ecosa'],
#  ['nectar', 'bed', 'ny'],
#  ['nectar', 'bed'],
#  ['nectar', 'mattress', 'nyc'],
#  ['try', 'nectar'],
#  ['try', 'nectar'],
#  ['try', 'leesa', 'nectar'],
#  ['nectar', 'brick', 'shed', 'motor'],
#  ['nectar'],
#  ['purple', 'nectar'],
#  ['nectar'],
#  ['nectar'],
#  ['best', 'backpain', 'nectar'],
#  ['purple', 'casper', 'nectar'],
#  ['nectar', 'store', 'locator'],
#  ['googlenectar', 'retail'],
#  ['nectar'],
#  ['nectar', 'showroom'],
#  ['nectar'],
#  ['leesa', 'nectar', 'showroom'],
#  ['nectar'],
#  ['nectar', 'showroom', 'nyc'],
#  ['nectar', 'store'],
#  ['mattress', 'nyc', 'try', 'leesa', 'casper', 'nectar'],
#  ['nectar', 'mattress', 'test'],
#  ['casper', 'purple', 'nectar'],
#  ['try', 'nectar', 'manhattan'],
#  ['nectar'],
#  ['leesa', 'nectar'],
#  ['nectar'],
#  ['casper', 'nectar'],
#  ['nectar'],
#  ['nectar', 'store'],
#  ['try', 'nectar'],
#  ['nectar'],
#  ['nectar'],
#  ['nectar'],
#  ['brooklyn', 'bedding'],
#  ['helix'],
#  ['winkbeds'],
#  ['winkbed'],
#  ['winkbed', 'showroom'],
#  ['saatva'],
#  ['wink'],
#  ['test', 'mattress', 'brooklyn', 'bedding'],
#  ['brooklyn'],
#  ['purple'],
#  ['airweave'],
#  [],
#  ['wink'],
#  ['leesa'],
#  ['winkwebsite'],
#  [],
#  ['brookyln', 'bedding'],
#  ['airweave'],
#  ['bear', 'mattress'],
#  ['dreamcloud'],
#  ['nectar'],
#  ['mattrees'],
#  ['wink'],
#  ['brookly', 'bedding'],
#  ['brooklyn', 'bedding', 'store'],
#  ['winkbed'],
#  ['nectar'],
#  ['saatva'],
#  ['leesa', 'mattress'],
#  ['leesa'],
#  ['leesa', 'casper', 'showroom'],
#  ['leesa'],
#  ['leesa', 'purple', 'showroom'],
#  ['reddit', 'leesa'],
#  ['leesa'],
#  ['leesa', 'showroom'],
#  ['leesa'],
#  ['leesa'],
#  ['test', 'leesa', 'mattress'],
#  ['mattress', 'leesa', 'casper'],
#  ['leesa', 'nyc'],
#  ['leesa', 'ahowroom'],
#  ['referred', 'leesa'],
#  ['try', 'leesa', 'mattress'],
#  ['try', 'leesa', 'nectar'],
#  ['leesa', 'mattress', 'nyc'],
#  ['leesa'],
#  ['leesa', 'store'],
#  ['leesa', 'mattress'],
#  ['try', 'leesa', 'mattress'],
#  ['leesa', 'showroom'],
#  ['try', 'leesa', 'mattress'],
#  ['salesman', 'leesa'],
#  ['leesa', 'nectar', 'showroom'],
#  ['mattress', 'nyc', 'try', 'leesa', 'casper', 'nectar'],
#  ['casper', 'leesa', 'showroom'],
#  ['leesa', 'hybrid', 'mattress', 'showroom'],
#  ['leesa'],
#  ['leesa', 'store', 'ny'],
#  ['leesa', 'saatva'],
#  ['leesa', 'nectar'],
#  ['leesa', 'mattress', 'yelp'],
#  ['yelp', 'mattress', 'bed'],
#  ['yelp', 'casper'],
#  ['mattress', 'store', 'yelp'],
#  ['yelp', 'mattress', 'store'],
#  ['leesa', 'mattress', 'yelp'],
#  ['mattress', 'store'],
#  ['mattress', 'store', 'nyc'],
#  ['brooklyn', 'bedding', 'store'],
#  ['best', 'mattress', 'store'],
#  ['mattress', 'store'],
#  ['nectar', 'store'],
#  ['bedding', 'store'],
#  ['mattress', 'store', 'nyc'],
#  ['matress', 'store'],
#  ['mattress', 'store', 'testing'],
#  ['matfress', 'store', 'manhattan'],
#  ['ny', 'mattress', 'store'],
#  ['mattress', 'store'],
#  ['mattress', 'store', 'nyc'],
#  ['mattress', 'store'],
#  ['mattress', 'store', 'ny'],
#  ['nyc', 'mattress', 'store'],
#  ['mattress', 'store', 'ny'],
#  ['saatva', 'innerspring', 'nyc', 'store'],
#  ['nest', 'store'],
#  ['mattress', 'store'],
#  ['mattress', 'store'],
#  ['mattress', 'store', 'yelp'],
#  ['mattress', 'store', 'saatva'],
#  ['mattress', 'store'],
#  ['mattress', 'store'],
#  ['mattress', 'store', 'manhattan'],
#  ['yelp', 'mattress', 'store'],
#  ['stomach', 'sleeper', 'mattress', 'store', 'ny'],
#  ['mattress', 'store'],
#  ['sleep', 'mattress', 'store'],
#  ['mattress', 'store'],
#  ['nyc', 'bed', 'store'],
#  ['bed', 'city'],
#  ['mattress', 'store', 'nyc'],
#  ['nectar', 'nyc'],
#  ['saatva', 'mattress', 'nyc'],
#  ['mattress', 'testing', 'nyc'],
#  ['mattress', 'nyc'],
#  ['leesa', 'nyc'],
#  ['mattress', 'store', 'nyc'],
#  ['bed', 'nyc'],
#  ['saatva', 'innerspring', 'nyc', 'store'],
#  ['purple', 'nyc'],
#  ['bed', 'nyc'],
#  ['mattress', 'nyc'],
#  ['best', 'mattress', 'store', 'city'],
#  ['mattress', 'showroom', 'ny', 'city'],
#  ['purple', 'mattress', 'ny', 'city'],
#  [],
#  ['casper', 'nyc'],
#  ['leesa', 'casper', 'showroom'],
#  ['mattress', 'casper'],
#  ['casper', 'mattress'],
#  ['casper', 'showroom'],
#  ['casper'],
#  ['casper', 'try', 'nyc'],
#  ['casper', 'showroom'],
#  ['casper', 'mattress', 'nyc'],
#  ['casper', 'mattress', 'try', 'ny'],
#  ['purple', 'casper'],
#  ['purple', 'nectar', 'casper'],
#  ['casper', 'nectar', 'showroom'],
#  ['casper', 'avocado', 'sterling'],
#  ['casper', 'mattress'],
#  ['yelp', 'casper'],
#  ['casper', 'showroom', 'nyc'],
#  ['try', 'casper'],
#  ['casper'],
#  ['casper', 'recommendation'],
#  ['try', 'casper', 'nectar'],
#  ['casper', 'store', 'representative'],
#  ['purple', 'showroom', 'casper'],
#  ['referred', 'casper'],
#  ['mattress', 'leesa', 'casper'],
#  ['nearest', 'casper', 'store'],
#  ['casper', 'employee'],
#  ['casper', 'matress', 'nyc'],
#  ['sleep', 'casper'],
#  ['try', 'casper'],
#  ['casper'],
#  ['casper', 'recommended'],
#  ['casper'],
#  ['casper', 'store'],
#  ['casper', 'showroom'],
#  ['purple', 'casper', 'nectar'],
#  ['tuft', 'needle', 'casper'],
#  ['casper'],
#  ['casper', 'store'],
#  ['casper', 'tuft', 'nyc'],
#  ['showroom', 'brooklyn', 'bedding', 'casper', 'nyc'],
#  ['mattress', 'nyc', 'try', 'leesa', 'casper', 'nectar'],
#  ['casper'],
#  ['casper'],
#  ['casper', 'leesa', 'showroom'],
#  ['casper', 'mattress', 'store'],
#  ['casper', 'purple', 'nectar'],
#  ['casper', 'mattress'],
#  ['casper'],
#  ['casper', 'nectar'],
#  ['casper', 'try'],
#  ['buy', 'saatva', 'bed'],
#  ['try', 'saatva'],
#  ['try', 'saatva', 'mattress'],
#  ['try', 'nectar'],
#  ['try', 'mattress'],
#  ['try', 'mattress'],
#  ['try', 'mattress', 'nyc'],
#  ['try', 'casper'],
#  ['buy', 'saatva'],
#  ['try', 'mattress'],
#  ['try', 'saatvs', 'mattress'],
#  ['try', 'saatva', 'mattress'],
#  ['test', 'purple', 'mattress'],
#  ['manhattan', 'try', 'mattress'],
#  ['try', 'purple', 'mattress'],
#  ['try', 'mattress'],
#  ['try', 'saatva', 'mattress'],
#  ['try', 'brooklyn', 'bedding'],
#  ['sleep', 'casper'],
#  ['try', 'dreamcloud', 'mattress'],
#  ['view', 'saatva', 'mattress'],
#  ['try', 'nectar'],
#  ['test', 'brooklyn', 'bedding'],
#  ['try', 'saatva', 'brooklyn', 'bedding', 'bear'],
#  ['test', 'mattress'],
#  ['try', 'puffy', 'mattress'],
#  ['brentwood', 'mattress', 'try'],
#  ['try', 'mattress'],
#  ['try', 'leesa', 'mattress'],
#  ['try', 'dreamcloud'],
#  ['try', 'mattress'],
#  ['try', 'bloom', 'hybrid'],
#  ['saatva', 'mattress'],
#  ['try', 'purple'],
#  ['try', 'saatva', 'mattress'],
#  ['try', 'winkbed'],
#  ['buy', 'best', 'hard', 'mattress'],
#  ['buy', 'saatva', 'bed'],
#  ['buy', 'saatva'],
#  ['buy', 'mattress'],
#  ['buy', 'best', 'hard', 'mattress'],
#  ['buy', 'saatva', 'bed'],
#  ['try', 'saatva'],
#  ['try', 'saatva', 'mattress'],
#  ['saatva', 'retailer'],
#  ['saatva', 'store'],
#  ['saatva', 'mattress', 'try'],
#  ['saatva'],
#  ['saatva', 'customer', 'service'],
#  ['saatva'],
#  ['saatva', 'trying', 'store'],
#  ['saatva', 'showroom'],
#  ['saatva'],
#  ['saatva'],
#  ['saatva', 'mattress', 'nyc'],
#  ['buy', 'saatva'],
#  ['matresses', 'saatva'],
#  ['saatva', 'mattress'],
#  ['try', 'saatva', 'nyc'],
#  ['saatva', 'mattress', 'showroom'],
#  ['mattress', 'stress', 'nyc', 'saatva', 'best', 'cool', 'mattress', 'saatva'],
#  ['showroom', 'saatva'],
#  ['saatva'],
#  ['try', 'saatva', 'mattress'],
#  ['saatva', 'showroom', 'nyc'],
#  ['loom', 'leaf', 'saatva'],
#  ['saatva', 'ny'],
#  ['saatva', 'purple'],
#  ['saatva', 'nyc', 'showroom'],
#  ['saatva', 'call', 'center'],
#  ['saatva', 'store'],
#  ['saatva', 'luxury'],
#  ['saatva', 'nyc'],
#  ['saatva'],
#  ['try', 'saatva', 'mattress'],
#  ['view', 'saatva', 'mattress'],
#  ['saatva'],
#  ['test', 'saatva', 'mattress'],
#  ['try', 'saatva'],
#  ['best', 'mattress', 'saatva'],
#  ['try', 'saatva', 'mattress'],
#  ['saatva'],
#  ['try', 'saatva', 'brooklyn', 'bedding', 'bear'],
#  ['husband', 'saatva'],
#  ['saatva', 'bed'],
#  ['saatva', 'innerspring', 'nyc', 'store'],
#  ['saatva', 'mirror', 'sleep'],
#  ['saatva'],
#  ['saatva', 'try'],
#  ['mattress', 'store', 'saatva'],
#  ['try', 'saatva', 'mattress', 'nyc'],
#  ['saatva', 'try'],
#  ['saatva', 'showroom', 'nyc'],
#  ['saatva', 'try', 'store'],
#  ['saatva', 'try'],
#  ['back', 'pain', 'saatva', 'test'],
#  ['sit', 'saatva'],
#  ['saatva'],
#  ['showroom', 'saatva'],
#  ['saatva'],
#  ['saatva', 'nyc'],
#  ['try', 'saatva'],
#  ['saatva', 'mattress'],
#  ['try', 'saatva'],
#  ['saatva', 'showroom'],
#  ['leesa', 'saatva'],
#  ['saatva'],
#  ['saatva', 'mattress'],
#  ['saatva'],
#  ['try', 'saatva', 'mattress'],
#  ['try', 'saatva', 'mattress'],
#  ['saatva'],
#  ['research', 'saatva'],
#  ['brooklyn', 'bedding'],
#  ['brooklyn', 'bedding'],
#  ['brooklyn', 'bedding', 'aurora'],
#  ['brooklyn', 'bedding', 'mattress'],
#  ['brooklyn', 'bedding'],
#  ['showroom', 'nyc', 'brooklyn', 'bedding'],
#  ['brooklyn', 'bedding', 'referral'],
#  ['brooklyn', 'bedding', 'locator'],
#  ['test', 'mattress', 'brooklyn', 'bedding'],
#  ['brooklyn', 'bedding', 'showroom'],
#  ['brooklyn', 'bedding'],
#  ['best', 'brooklyn'],
#  ['brooklyn', 'bedding', 'store', 'ny'],
#  ['brooklyn'],
#  ['brooklyn', 'bedding', 'locate'],
#  ['brooklyn', 'bedding'],
#  ['try', 'brooklyn', 'bedding'],
#  ['brooklyn', 'bedding'],
#  ['try', 'brooklyn', 'bedding'],
#  ['test', 'brooklyn', 'bedding'],
#  ['brooklyn', 'bedding'],
#  ['brooklyn', 'spartan', 'try'],
#  ['brooklyn', 'beddingcom'],
#  ['brooklyn', 'bedding', 'tryout'],
#  ['brooklyn', 'bedding'],
#  ['brooklyn', 'bedding', 'nyc'],
#  ['brooklyn', 'bedding'],
#  ['brooklyn', 'bedding', 'manhattan'],
#  ['brooklyn', 'bedding', 'store'],
#  ['brooklyn'],
#  ['brooklyn', 'bedding', 'nyc'],
#  ['brooklyn'],
#  ['winkbeds'],
#  ['winkbeds'],
#  ['winkbeds', 'testing'],
#  ['winkbeds'],
#  ['winkbeds'],
#  ['winkbeds', 'try'],
#  ['purple', 'mattress'],
#  ['purple'],
#  ['leesa', 'purple', 'showroom'],
#  ['purple', 'casper'],
#  ['purple', 'nectar', 'casper'],
#  ['purple', 'showroom'],
#  ['satvaa', 'purple'],
#  ['showroom', 'purple'],
#  ['nectar', 'purple'],
#  ['purple', 'nectar'],
#  ['purple', 'mattress'],
#  ['purple', 'showroom'],
#  ['purple'],
#  ['purple', 'showroom'],
#  ['try', 'purple', 'mattress', 'nyc'],
#  ['purple', 'showroom', 'nyc'],
#  ['purple', 'mattress', 'showroom'],
#  ['purple', 'try'],
#  ['purple'],
#  ['purple', 'mattress', 'store'],
#  ['purple'],
#  ['purple', 'manhattan'],
#  ['test', 'purple', 'mattress'],
#  ['test', 'purple', 'mattress'],
#  ['try', 'purple', 'nyc'],
#  ['try', 'purple', 'mattress'],
#  ['try', 'purple', 'mattress'],
#  ['saatva', 'purple'],
#  ['purple', 'showroom', 'casper'],
#  ['purple', 'try'],
#  ['test', 'purple', 'ny'],
#  ['purple', 'store'],
#  ['purple', 'matress'],
#  ['purple', 'mattress', 'nyc'],
#  ['try', 'purple'],
#  ['purple', 'nectar'],
#  ['purple', 'mattress'],
#  ['nyc', 'mattress', 'store', 'purple'],
#  ['purple', 'mattress', 'store'],
#  ['purple', 'casper', 'nectar'],
#  ['purple', 'tryout'],
#  ['purple', 'mattress'],
#  ['purple'],
#  ['purple', 'nyc'],
#  ['purple', 'mattress'],
#  ['purple', 'mattress', 'nyc'],
#  ['purple'],
#  ['casper', 'purple', 'nectar'],
#  ['purple', 'mattress'],
#  ['purple', 'mattress'],
#  ['test', 'purple'],
#  ['test', 'purple'],
#  ['try', 'purple'],
#  ['purple', 'mattress', 'ny', 'city'],
#  ['airweave'],
#  ['winked', 'bed'],
#  ['helix'],
#  ['helix'],
#  ['helix', 'dusk'],
#  ['referral', 'helix'],
#  ['helix', 'showroom'],
#  ['helix'],
#  ['wink', 'bed'],
#  ['nyc', 'wink', 'bed'],
#  ['winkbed'],
#  ['winkbed', 'testing', 'store'],
#  ['winkbed', 'store'],
#  ['wink'],
#  ['try', 'winkbed'],
#  ['showroom', 'wink'],
#  ['winkbed'],
#  ['winkbed', 'showroom'],
#  ['wink'],
#  ['aurora', 'brooklyn', 'bedding', 'winkbedding'],
#  ['winkbeds', 'testing'],
#  ['winkbed'],
#  ['winkbed'],
#  ['winkbed', 'try'],
#  ['winkbed', 'showroom'],
#  ['wink', 'bed'],
#  ['winkbeds'],
#  ['wink'],
#  ['winkbed', 'ny'],
#  ['winkbed', 'nyc'],
#  ['winkbed', 'customer', 'service', 'team'],
#  ['wink'],
#  ['winkbed'],
#  ['wink'],
#  ['tuckcom', 'winkbed'],
#  ['winkbeds', 'try'],
#  ['wink', 'sleep'],
#  ['winkbed', 'mattress'],
#  ['wink', 'showroom', 'nyc'],
#  ['wink'],
#  ['winkbed', 'try'],
#  ['wink', 'bed'],
#  ['try', 'winkbed'],
#  ['showroom', 'wink'],
#  ['brooklying', 'bedding', 'showroom'],
#  ['brooklying', 'bedding'],
#  ['comparison', 'mattress'],
#  ['mattress', 'comparison', 'caspar'],
#  ['mattress', 'comparison'],
#  ['comparison', 'mattress', 'store'],
#  ['saatva', 'customer', 'service'],
#  ['winkbed', 'customer', 'service', 'team'],
#  ['bear', 'customer', 'service'],
#  ['saatvz', 'mattress'],
#  ['test', 'bed', 'ny'],
#  ['test', 'mattress'],
#  ['test', 'mattress', 'brooklyn', 'bedding'],
#  ['test', 'foam', 'mattress'],
#  ['testing', 'mattress'],
#  ['mattress', 'store', 'testing'],
#  ['test', 'purple', 'mattress'],
#  ['test', 'mattress'],
#  ['test', 'purple', 'mattress'],
#  ['testing', 'mattreses'],
#  ['test', 'purple', 'ny'],
#  ['test', 'leesa', 'mattress'],
#  ['mattress', 'test', 'center'],
#  ['test', 'saatva', 'mattress'],
#  ['test', 'brooklyn', 'bedding'],
#  ['test', 'mattress'],
#  ['test', 'mattress'],
#  ['back', 'pain', 'saatva', 'test'],
#  ['test', 'mattreess'],
#  ['nectar', 'mattress', 'test'],
#  ['testing'],
#  ['test', 'purple'],
#  ['test', 'purple'],
#  ['best', 'bed', 'back', 'issue', 'test'],
#  ['mattress', 'shop', 'testing'],
#  ['test', 'mattress'],
#  ['tuft', 'needle'],
#  ['tuft', 'needle', 'referred'],
#  ['tuft', 'needle'],
#  ['tuft', 'needle', 'store'],
#  ['tuft', 'needle', 'store', 'locator'],
#  ['tuft', 'needle', 'casper'],
#  ['casper', 'tuft', 'nyc'],
#  ['tuft', 'needle', 'try'],
#  ['tuft', 'en', 'neadel'],
#  ['tuft', 'needle'],
#  ['tuft', 'needle', 'referred'],
#  ['tuft', 'needle'],
#  ['tuft', 'needle', 'store'],
#  ['tuft', 'needle', 'store', 'locator'],
#  ['tuft', 'needle', 'casper'],
#  ['tuft', 'needle', 'try'],
#  ['try', 'tuten', 'needle'],
#  ['brooklyn', 'bedding', 'referral'],
#  ['referral', 'helix'],
#  ['boxed', 'mattress', 'try', 'store'],
#  ['leesa'],
#  ['winkbed'],
#  ['leesa', 'purple', 'showroom'],
#  ['winkbed'],
#  ['winkbed'],
#  ['winkbed', 'testing', 'store'],
#  ['winkbed', 'store'],
#  ['winkbed'],
#  ['winkbed', 'showroom'],
#  ['aurora', 'brooklyn', 'bedding', 'winkbed', 'ding'],
#  ['winkbed', 'testing'],
#  ['winkbed'],
#  ['winkbed'],
#  ['winkbed', 'try'],
#  ['winkbed', 'showroom'],
#  ['winkbed'],
#  ['winkbed', 'ny'],
#  ['winkbed', 'nyc'],
#  ['winkbed', 'customer', 'service', 'team'],
#  ['winkbed'],
#  ['winkbed'],
#  ['winkbed', 'try'],
#  ['winkbed', 'mattress'],
#  ['winkbed', 'try'],
#  ['winkbed'],
#  ['try'],
#  ['nectar', 'research'],
#  ['research', 'saatva'],
#  ['sleepare', 'showroom'],
#  ['sleepare'],
#  ['sleepare', 'mattress'],
#  ['sleepare', 'nyc'],
#  ['sleepare'],
#  ['sleepare'],
#  ['mattress', 'review'],
#  ['mattress', 'review'],
#  ['reddit', 'leesa', 'review'],
#  ['pillow', 'review'],
#  ['brooklyn', 'bedding', 'review'],
#  ['mattrress', 'review'],
#  ['helix', 'review'],
#  ['tuck', 'sleep', 'review'],
#  ['tuck', 'review'],
#  ['sleepare', 'review', 'mattress', 'review'],
#  ['mattress', 'review'],
#  ['park', 'slope', 'parent', 'review'],
#  ['review'],
#  ['mattress', 'review'],
#  ['saatva', 'retailer'],
#  ['safra', 'retailer'],
#  ['bear', 'retailer'],
#  ['retailer'],
#  ['brooklyn', 'bedding', 'aurora'],
#  ['aurora', 'brooklyn', 'bedding', 'winkbedding'],
#  ['aurora', 'brooklyn', 'bedding'],
#  ['necter', 'mattress'],
#  ['necter', 'bed'],
#  ['pillow', 'shredded', 'latex', 'queen', 'cotton', 'cover'],
#  ['pillow'],
#  ['pillow', 'review'],
#  ['pillow', 'shredded', 'latex', 'queen', 'cotton', 'cover'],
#  ['latex', 'mattress', 'nyc'],
#  ['latex'],
#  ['mattress', 'latex'],
#  ['talalay', 'latex'],
#  ['pillow', 'shredded', 'latex', 'queen', 'cotton', 'cover'],
#  ['pillow'],
#  ['pillow'],
#  ['pillow', 'shredded', 'latex', 'queen', 'cotton', 'cover'],
#  ['pillow'],
#  ['pillow', 'review'],
#  ['winkbed', 'testing', 'store'],
#  ['testing', 'mattress'],
#  ['testing', 'mattreses'],
#  ['mattress', 'testing', 'nyc'],
#  ['testing'],
#  ['mattress'],
#  ['matress', 'store'],
#  ['casper', 'avocado', 'sterling'],
#  ['purple', 'mattress'],
#  ['store', 'try', 'mattress'],
#  ['mattress', 'store'],
#  ['matress', 'store'],
#  [],
#  ['mattress'],
#  ['mattress', 'u'],
#  ['est', 'casper', 'store'],
#  ['mattress', 'store'],
#  ['mattress'],
#  ['mattress'],
#  ['mattress', 'store'],
#  ['mattress', 'store'],
#  ['cooling', 'mattress'],
#  ['cooling', 'mattress'],
#  ['saatva', 'store'],
#  ['mattress', 'stress', 'nyc', 'saatva', 'best', 'cool', 'mattress', 'saatva'],
#  ['best', 'mattress', 'store', 'nyc'],
#  ['best', 'mattress', 'store'],
#  ['best', 'mattress'],
#  ['best', 'mattress', 'nyc'],
#  ['best', 'mattress', 'store'],
#  ['best', 'mattress'],
#  ['best', 'mattress'],
#  ['best', 'mattress'],
#  ['best', 'brooklyn'],
#  ['mattress', 'stress', 'nyc', 'saatva', 'best', 'cool', 'mattress', 'saatva'],
#  ['best', 'mattress'],
#  ['best', 'mattress', 'boxspring', 'ny'],
#  ['best', 'nyc', 'mattress', 'showroom'],
#  ['best', 'hybrid', 'mattress'],
#  ['best', 'mattress', 'saatva'],
#  ['best', 'bed'],
#  ['best', 'mattress', 'ny'],
#  ['best', 'matress'],
#  ['best', 'hybrid', 'bedding'],
#  ['best', 'backpain', 'nectar'],
#  ['best', 'mattress', 'store', 'try', 'presdure'],
#  ['best', 'mattress', 'showroom'],
#  ['best', 'mattress', 'try'],
#  ['nyc', 'mattress', 'best', 'store'],
#  ['best', 'nyc', 'mattress', 'store'],
#  ['mattress', 'best'],
#  ['good', 'mattress', 'best', 'mattress'],
#  ['best', 'mattress', 'good', 'mattress'],
#  ['best', 'bed', 'back', 'issue', 'test'],
#  ['nyc', 'strategy', 'best', 'mattress'],
#  ['best', 'mattress', 'store', 'city'],
#  ['buy', 'best', 'hard', 'mattress'],
#  ['mattress', 'shworoom'],
#  ['new', 'york', 'city', 'showroom'],
#  ['nyc', 'showroom'],
#  ['saatva'],
#  ['mattress', 'try', 'store'],
#  ['bed', 'nyc'],
#  ['mattress'],
#  ['bed', 'nyc'],
#  ['test', 'mattress'],
#  ['bed', 'showroom'],
#  ['mattress', 'store'],
#  ['best', 'mattress', 'spring', 'ny'],
#  ['bed'],
#  ['bed', 'showroom', 'nyc'],
#  ['bed', 'showroom'],
#  ['bed', 'soho'],
#  ['mattress'],
#  ['bed', 'store'],
#  ['best', 'bed', 'back', 'issue', 'test'],
#  ['mattress'],
#  ['bed', 'showroom'],
#  ['showroom', 'nyc', 'brooklyn', 'bedding'],
#  ['mattress', 'stress', 'nyc', 'saatva', 'best', 'cool', 'mattress', 'saatva'],
#  ['mattress', 'nyc', 'try', 'leesa', 'casper', 'nectar'],
#  ['try', 'mattress'],
#  ['nectar', 'distributor'],
#  ['nectar', 'distributor'],
#  ['shoeroom'],
#  ['casper', 'showroom'],
#  ['comparison', 'mattress', 'store'],
#  ['casper'],
#  ['try', 'mattress'],
#  ['casper', 'showroom'],
#  ['purple', 'showroom'],
#  ['brooklyn', 'bedding', 'locator'],
#  ['tuft', 'needle', 'store', 'locator'],
#  ['nectar', 'store', 'locator'],
#  ['try', 'onlinebeds'],
#  ['test', 'mattress'],
#  ['try', 'onilne', 'bed'],
#  ['mattress'],
#  ['mattress'],
#  ['try', 'mattress'],
#  ['sit', 'saatva'],
#  ['test', 'purple'],
#  ['try', 'onlinebeds'],
#  ['tuft', 'needle', 'referred'],
#  ['mattress', 'trial'],
#  ['mattress', 'trial', 'store'],
#  ['mattress', 'trial'],
#  ['nectar', 'brick', 'motar', 'store'],
#  ['bed', 'brick', 'mortar'],
#  ['nectar', 'brick', 'shed', 'motor'],
#  ['nectar', 'brick', 'motar', 'store'],
#  ['organic', 'mattress', 'store'],
#  ['organic', 'mattress'],
#  ['organic', 'mattress'],
#  ['trying', 'mattress'],
#  ['saatva', 'trying', 'store'],
#  ['trying', 'mattress'],
#  ['casper', 'showroom'],
#  ['mattressngooglensearch'],
#  ['saatva'],
#  ['consumer'],
#  ['casper'],
#  ['casper'],
#  ['nectar'],
#  ['try', 'bed', 'ny'],
#  ['comparison', 'mattress', 'store'],
#  ['casper'],
#  ['saatva'],
#  ['mattress'],
#  ['saatva'],
#  ['try', 'mattress'],
#  ['nectar'],
#  ['mattress'],
#  ['mattress'],
#  ['matress', 'matressfirm'],
#  ['matress'],
#  ['airweave'],
#  ['saatva', 'luxury'],
#  ['medium', 'mattress', 'sciatica'],
#  ['mattress', 'showroom'],
#  ['mattress'],
#  ['reddit', 'leesa'],
#  [],
#  [],
#  ['brooklyn', 'bedding'],
#  ['helix'],
#  ['sleepare', 'mattress'],
#  ['mattress'],
#  ['mattress'],
#  ['try', 'mattress'],
#  ['nyc', 'showroom'],
#  ['showroom', 'nyc', 'brooklyn', 'bedding'],
#  ['mattress', 'showroom'],
#  ['leesa', 'purple', 'showroom'],
#  ['showroom', 'purple'],
#  ['mattress', 'showroom', 'ny'],
#  ['nectar', 'showroom'],
#  ['showroom', 'mattress'],
#  ['mattress', 'showroom'],
#  ['leesa', 'nectar', 'showroom'],
#  ['showroom', 'brooklyn', 'bedding', 'casper', 'nyc'],
#  ['lack', 'bed', 'showroom'],
#  ['mattress', 'showroom', 'manhattan'],
#  ['back', 'bed'],
#  ['nectar', 'retail'],
#  ['test', 'mattreess'],
#  ['brooklyn', 'bedding'],
#  ['reddit', 'leesa'],
#  ['reddit', 'mattress', 'nyc'],
#  [],
#  ['saatva', 'customer', 'service'],
#  ['winkbed', 'customer', 'service', 'team'],
#  ['bear', 'customer', 'service'],
#  ['puffy', 'mattress'],
#  ['puffy', 'bear'],
#  ['try', 'puffy'],
#  ['puffy', 'brooklyn', 'bedding'],
#  ['try', 'puffy', 'mattress'],
#  ['try', 'puffy', 'mattress'],
#  ['puffy'],
#  ['puffy', 'cloud', 'try'],
#  ['puffy', 'mattress', 'showroom'],
#  ['mattress', 'shop'],
#  ['ny', 'mattress', 'shop'],
#  ['shop'],
#  ['mattress', 'shop'],
#  ['mattress', 'shop', 'testing'],
#  [],
#  ['checking', 'lull'],
#  ['checking', 'lull'],
#  ['lull'],
#  ['test', 'mattress'],
#  ['sit', 'saatva'],
#  ['bedding', 'company'],
#  ['mattress', 'company'],
#  ['nectar', 'try'],
#  ['compare', 'mattress', 'brooklyn', 'bedding'],
#  ['compare', 'matresses', 'ny'],
#  ['compare', 'matresses'],
#  ['compare', 'mattress'],
#  ['compare', 'bed'],
#  ['compare'],
#  ['compare', 'mattress'],
#  ['compare', 'mattress', 'wirecutter'],
#  ['mattress', 'ny', 'compare'],
#  ['compare', 'mattress', 'brooklyn', 'bedding'],
#  ['compare', 'mattress', 'wirecutter'],
#  ['went',
#   'store',
#   'tried',
#   'different',
#   'mattress',
#   'liked',
#   'brooklyn',
#   'bedding'],
#  ['satvaa', 'mattress'],
#  ['satvaa', 'purple'],
#  ['satvaa'],
#  ['satvaa', 'showroom'],
#  ['tryout', 'satvaa'],
#  ['satvaa', 'showroom'],
#  ['satvaa', 'try'],
#  ['satvaa', 'tuckcom'],
#  ['satvaa'],
#  ['matress', 'store'],
#  ['mattress'],
#  ['mattress', 'store'],
#  ['mattress', 'store'],
#  ['mattress', 'nyc', 'tryout'],
#  ['tryout', 'satvaa'],
#  ['purple', 'tryout'],
#  ['brooklyn', 'bedding', 'tryout'],
#  ['try', 'onilne', 'bed'],
#  ['saatva'],
#  ['saatva'],
#  ['saatva'],
#  ['try', 'saatva'],
#  ['casper', 'nectar', 'showroom'],
#  ['purple', 'nectar'],
#  ['find', 'showroom'],
#  ['reddit', 'mattress', 'manhattan'],
#  ['reddit', 'mattress', 'nyc'],
#  ['nectar'],
#  ['nest', 'bedding'],
#  ['nest'],
#  ['nest'],
#  ['nest', 'store'],
#  ['nest', 'recommend'],
#  ['nest', 'bedding', 'recommendation'],
#  ['nest', 'people'],
#  ['nest'],
#  ['recommended', 'nest'],
#  ['nest', 'store'],
#  ['foam', 'mattress'],
#  ['test', 'foam', 'mattress'],
#  ['foam'],
#  ['foam', 'mattress'],
#  ['safra', 'retailer'],
#  ['safra', 'retailer'],
#  ['wink'],
#  ['wink', 'leep'],
#  ['casper', 'avocado', 'sterling'],
#  ['avocado', 'mattress'],
#  ['avocado', 'showroom'],
#  ['avocado', 'found', 'said', 'try'],
#  ['avocado'],
#  ['casper', 'avocado', 'sterling'],
#  ['gogglecom'],
#  ['savata'],
#  ['best', 'mattress'],
#  ['best', 'mattress'],
#  ['mattress', 'soho'],
#  ['bed', 'soho'],
#  ['tuckcom'],
#  ['tuckcom', 'winkbed'],
#  ['satvaa', 'tuckcom'],
#  ['mattressed', 'try'],
#  ['try', 'mattress'],
#  ['mattress'],
#  ['mattress', 'store'],
#  ['purple', 'nectar'],
#  ['casper', 'mattress'],
#  [],
#  ['stress', 'store'],
#  ['satva'],
#  ['mattress'],
#  ['mattress'],
#  ['saatva'],
#  ['mattress'],
#  ['mattress', 'store'],
#  ['mattress', 'store'],
#  ['mattress'],
#  ['nectar'],
#  ['nectar'],
#  ['mattress'],
#  ['reddit', 'mattress', 'manhattan'],
#  ['ped', 'casper'],
#  ['mattress'],
#  ['casper', 'mattress'],
#  ['mattress'],
#  ['mattress'],
#  ['nectar'],
#  ['nectar'],
#  ['mattress'],
#  ['test', 'mattrees'],
#  ['mattress', 'stress', 'nyc', 'saatva', 'best', 'cool', 'mattress', 'saatva'],
#  ['bear', 'representitive'],
#  ['puffy', 'bear'],
#  ['bear', 'mattress', 'store'],
#  ['try', 'saatva', 'brooklyn', 'bedding', 'bear'],
#  ['bear'],
#  ['bear', 'mattress'],
#  ['bear', 'customer', 'service'],
#  ['bear', 'retailer'],
#  ['bear'],
#  ['bear', 'representitive'],
#  ['casper', 'showroom', 'nyc'],
#  ['top', 'mattress', 'store'],
#  ['top', 'rated', 'mattress'],
#  ['new', 'mattress', 'floor'],
#  ['satva', 'mattress'],
#  ['satva', 'purple'],
#  ['satva'],
#  ['satva', 'showroom'],
#  ['satva'],
#  ['satva'],
#  ['tryout', 'satva'],
#  ['satva', 'showroom'],
#  ['satva', 'try'],
#  ['satva', 'tuckcom'],
#  ['satva'],
#  ['dream', 'cloud'],
#  ['dream', 'cloud'],
#  ['dream', 'cloud'],
#  ['dream', 'cloud', 'mattress'],
#  ['dream', 'cloud'],
#  ['try', 'dream', 'cloud', 'mattress'],
#  ['dream', 'cloud', 'showroom'],
#  ['dream', 'cloud', 'retail', 'store'],
#  ['try', 'dream', 'cloud'],
#  ['dream', 'cloud'],
#  ['dream', 'cloud'],
#  ['dreamcloud'],
#  ['dreamcloud', 'mattress'],
#  ['dreamcloud'],
#  ['try', 'dreamcloud', 'mattress'],
#  ['dreamcloud', 'showroom'],
#  ['dreamcloud', 'retail', 'store'],
#  ['try', 'dreamcloud'],
#  ['dreamcloud'],
#  ['puffy', 'cloud', 'try'],
#  ['mattress', 'ny'],
#  [],
#  ['brookyling', 'bedding'],
#  ['lessa'],
#  ['lessa', 'mattress'],
#  ['lessa'],
#  ['compare', 'matresses', 'ny'],
#  ['matresses', 'saatva'],
#  ['compare', 'matresses'],
#  ['matresses', 'try'],
#  ['matresses'],
#  ['bed', 'bed', 'toddler'],
#  ['nectar', 'store'],
#  ['try', 'purple', 'mattress', 'nyc'],
#  ['saatvia'],
#  ['best', 'mattress'],
#  ['mattress', 'best'],
#  ['brooklyn', 'bedding', 'bed', 'store'],
#  [],
#  ['brooklyn', 'bedding', 'bed', 'store'],
#  ['maattress'],
#  ['brooklyn', 'bedding', 'store', 'ny'],
#  ['hybrid', 'retail'],
#  ['hybrid', 'mattress', 'retail'],
#  ['best', 'hybrid', 'mattress'],
#  ['best', 'hybrid', 'bedding'],
#  ['leesa', 'hybrid', 'mattress', 'showroom'],
#  ['try', 'bloom', 'hybrid'],
#  ['leeaa', 'hybrid'],
#  ['saatva', 'retailer'],
#  ['safra', 'retailer'],
#  ['hybrid', 'retail'],
#  ['hybrid', 'mattress', 'retail'],
#  ['dreamcloud', 'retail', 'store'],
#  ['googlenectar', 'retail'],
#  ['bear', 'retailer'],
#  ['retailer'],
#  ['satvaa', 'mattress'],
#  ['satvaa', 'showroom'],
#  ['satvaa'],
#  ['satv'],
#  ['satvaa', 'showroom'],
#  ['satvaa', 'try'],
#  ['top', 'rated', 'mattress'],
#  ['mattress', 'comparison', 'caspar'],
#  ['casper', 'recommendation'],
#  ['nest', 'bedding', 'recommendation'],
#  ['recommendation'],
#  ['brooklyn', 'bedding', 'locate'],
#  ...]

# %%
# remove empty list
cleaned_keywords_ = [list_keywords for list_keywords in cleaned_keywords if list_keywords != []]

# %%
# save original keywords
keywords_original = list()
for idx, key_words in enumerate(cleaned_keywords) :
    if key_words != []:
        keywords_original.append(df['keywords'].iloc[idx])

# %%
len(keywords_original)
# Out:
# 1125

# %%
len(cleaned_keywords_)
# Out:
# 1125

# %% [markdown]
# ### 3.3 Train Word2Vec on Custom Corpus
# We create Word2Vec model using our own data

# %%
start = time.time()

# set the logging format to get some basic updates.
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)

# set values for various parameters
num_features = 50    # Dimensionality of the hidden layer representation
min_word_count = 1   # Minimum word count to keep a word in the vocabulary
num_workers = multiprocessing.cpu_count()      # Number of threads to run in parallel set to total number of cpus.
context = 5          # Context window size (on each side)                                                       

# initialize and train the model
print("Training model...")
model = Word2Vec(cleaned_keywords_, workers=num_workers, size=num_features, min_count = min_word_count, window = context)

# save the model
model_name = "model_keywords"
model.save(model_name)

print('Total time: ' + str((time.time() - start)) + ' secs')
# Out:
# 2020-01-20 10:04:23,101 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2020-01-20 10:04:23,101 : INFO : collecting all words and their counts
# 2020-01-20 10:04:23,102 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-01-20 10:04:23,103 : INFO : collected 206 word types from a corpus of 2580 raw words and 1125 sentences
# 2020-01-20 10:04:23,104 : INFO : Loading a fresh vocabulary
# 2020-01-20 10:04:23,105 : INFO : effective_min_count=1 retains 206 unique words (100% of original 206, drops 0)
# 2020-01-20 10:04:23,106 : INFO : effective_min_count=1 leaves 2580 word corpus (100% of original 2580, drops 0)
# 2020-01-20 10:04:23,107 : INFO : deleting the raw counts dictionary of 206 items
# 2020-01-20 10:04:23,108 : INFO : sample=0.001 downsamples 63 most-common words
# 2020-01-20 10:04:23,108 : INFO : downsampling leaves estimated 972 word corpus (37.7% of prior 2580)
# 2020-01-20 10:04:23,109 : INFO : estimated required memory for 206 words and 50 dimensions: 185400 bytes
# 2020-01-20 10:04:23,110 : INFO : resetting layer weights
# 2020-01-20 10:04:23,117 : INFO : training model with 8 workers on 206 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2020-01-20 10:04:23,135 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-01-20 10:04:23,137 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-01-20 10:04:23,138 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-01-20 10:04:23,139 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-01-20 10:04:23,140 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-01-20 10:04:23,141 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-20 10:04:23,142 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-20 10:04:23,143 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-20 10:04:23,144 : INFO : EPOCH - 1 : training on 2580 raw words (951 effective words) took 0.0s, 86280 effective words/s
# 2020-01-20 10:04:23,154 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-01-20 10:04:23,155 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-01-20 10:04:23,156 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-01-20 10:04:23,157 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-01-20 10:04:23,158 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-01-20 10:04:23,159 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-20 10:04:23,159 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-20 10:04:23,160 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-20 10:04:23,162 : INFO : EPOCH - 2 : training on 2580 raw words (971 effective words) took 0.0s, 133994 effective words/s
# 2020-01-20 10:04:23,171 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-01-20 10:04:23,173 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-01-20 10:04:23,174 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-01-20 10:04:23,175 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-01-20 10:04:23,176 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-01-20 10:04:23,176 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-20 10:04:23,177 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-20 10:04:23,178 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-20 10:04:23,179 : INFO : EPOCH - 3 : training on 2580 raw words (996 effective words) took 0.0s, 104642 effective words/s
# 2020-01-20 10:04:23,197 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-01-20 10:04:23,198 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-01-20 10:04:23,200 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-01-20 10:04:23,202 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-01-20 10:04:23,203 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-01-20 10:04:23,204 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-20 10:04:23,206 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-20 10:04:23,208 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-20 10:04:23,209 : INFO : EPOCH - 4 : training on 2580 raw words (1004 effective words) took 0.0s, 73231 effective words/s
# 2020-01-20 10:04:23,219 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-01-20 10:04:23,220 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-01-20 10:04:23,221 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-01-20 10:04:23,222 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-01-20 10:04:23,222 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-01-20 10:04:23,223 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-20 10:04:23,224 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-20 10:04:23,225 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-20 10:04:23,226 : INFO : EPOCH - 5 : training on 2580 raw words (977 effective words) took 0.0s, 142993 effective words/s
# 2020-01-20 10:04:23,226 : INFO : training on a 12900 raw words (4899 effective words) took 0.1s, 45187 effective words/s
# 2020-01-20 10:04:23,227 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2020-01-20 10:04:23,228 : INFO : saving Word2Vec object under model_keywords, separately None
# 2020-01-20 10:04:23,229 : INFO : not storing attribute vectors_norm
# 2020-01-20 10:04:23,230 : INFO : not storing attribute cum_table
# C:\Users\user\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2020-01-20 10:04:23,235 : INFO : saved model_keywords
# Training model...
# Total time: 0.135603666305542 secs

# %%
# create average feature embedding for each keyword phrase
def vectorizer(keyword_phrase, model_keywords):
    vec = list()
    num_keyword = 0
    for keyword in keyword_phrase:
        try:
            if num_keyword == 0:
                vec = model_keywords.wv[keyword]
            else:
                vec = np.add(vec, model_keywords.wv[keyword])
            num_keyword += 1
        except:
            pass
    return (np.array(vec)/num_keyword)

# %%
keywords_vec=list()
keywords_in_vocab=list()
for idx, key_phrase in enumerate(cleaned_keywords_):
    if len(vectorizer(key_phrase, model).tolist())!=0:
        keywords_vec.append(vectorizer(key_phrase, model).tolist())
        keywords_in_vocab.append(key_phrase)
    #else:
        #print(idx)
        
# convert list to ndarray
X=np.array(keywords_vec, dtype=object)

# %%
len(X)
# Out:
# 1125

# %% [markdown]
# ### 3.4 Cluster Keywords Using K-Means
# We will cluster the keywords using KMeans. Since the keywords are represented as vectors, applying KMeans is easy to do since the clustering algorithm will simply look at differences between vectors (and centers).

# %%
def clustering_keywordvecs(keyword_vectors, num_clusters):
    # Initalize a k-means object and use it to extract centroids
    kmeans_clustering = KMeans(n_clusters = num_clusters, max_iter = 100, init='k-means++')
    idx = kmeans_clustering.fit_predict(keyword_vectors)
    
    return kmeans_clustering.cluster_centers_, idx

# %%
# get optimal k clusters
distorsions = []
for k in range(2, 12):
    kmeans = KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(X)
    distorsions.append(kmeans.inertia_)

fig = plt.figure(figsize=(10, 5))
plt.plot(range(2, 12), distorsions)
plt.grid(True)
plt.title('Elbow curve')
# Out:
# Text(0.5, 1.0, 'Elbow curve')

# %% [markdown]
# As we cannot see the optimal k with elbow method, we can try another method called Silhouette method. The silhouette value measures how similar a point is to its own cluster (cohesion) compared to other clusters (separation) -- Wikipedia. The range of the Silhouette value is between +1 and -1. A high value is desirable and indicates that the point is placed in the correct cluster. The Silhouette Score reaches its global maximum at the optimal k. This should ideally appear as a peak in the Silhouette Value-versus-k plot. Here is the plot for our own dataset:

# %%
from sklearn.metrics import silhouette_score

silh = []
kmax = 10

# dissimilarity would not be defined for a single cluster, thus, minimum number of clusters should be 2
for k in range(2, kmax+1):
    kmeans = KMeans(n_clusters = k, init='k-means++').fit(X)
    labels = kmeans.labels_
    silh.append(silhouette_score(X, labels, metric = 'euclidean'))
    
fig = plt.figure(figsize=(10, 5))
plt.plot(range(2, 11), silh)
plt.grid(True)
plt.title('Sillhoutte')
# Out:
# Text(0.5, 1.0, 'Sillhoutte')

# %% [markdown]
# From the curve image, the optimal number of cluster is 7.

# %%
# apply KMeans clustering to the keywords data with K=7
centers, clusters = clustering_keywordvecs(X, 7)

# %%
# assign list keywords of each cluster to variables
cluster_dict = dict()
keywords_clean = list()
cluster_ = list()
for index, keyword_vector in enumerate(keywords_in_vocab):
    try:
        #print(str(clusters[index]) + ":" + ' '.join(keyword_vector))
        #cluster_dict.update({' '.join(keyword_vector) : str(clusters[index])})
        keywords_clean.append(' '.join(keyword_vector))
        cluster_.append(str(clusters[index]))
    except IndexError:
        pass   
cluster_dict = {
    'cluster': cluster_,
    'keywords_clean': keywords_clean,
    'keywords_original': keywords_original
}

# %%
df_keyword_cluster = pd.DataFrame(cluster_dict)

# %%
df_keyword_cluster
# Out:
#      cluster               keywords_clean  \
# 0          0                       nectar
# 1          6        nectar mattress store
# 2          0                       nectar
# 3          0                       nectar
# 4          2              nectar showroom
# 5          0                   nectar try
# 6          0              nectar research
# 7          6              nectar mattress
# 8          0                   try nectar
# 9          6        nectar mattress store
# 10         0           nectar distributor
# 11         6              nectar mattress
# 12         3     nectar brick motar store
# 13         0                   nectar try
# 14         3         purple nectar casper
# 15         0                 nectar store
# 16         0                nectar purple
# 17         0               nectar matress
# 18         0                       nectar
# 19         0                       nectar
# 20         2              nectar showroom
# 21         0                   nectar try
# 22         1          try nectar mattress
# 23         0                 nectar store
# 24         0                   nectar nyc
# 25         3            try casper nectar
# 26         0                 nectar ecosa
# 27         3                nectar bed ny
# 28         0                   nectar bed
# 29         1          nectar mattress nyc
# ...      ...                          ...
# 1095       3                      bed nyc
# 1096       1          purple mattress nyc
# 1097       1              purple mattress
# 1098       6                     mattress
# 1099       1  mattress showroom manhattan
# 1100       3                         bear
# 1101       3     casper store resentative
# 1102       2                        leesa
# 1103       3                consumer orts
# 1104       3  casper store representative
# 1105       6            mattress location
# 1106       3       brooklyn bedding store
# 1107       3            air weave partner
# 1108       3                    air weave
# 1109       3             air weave dealer
# 1110       3                    air weave
# 1111       3                    air weave
# 1112       1           air weave mattress
# 1113       3                    air weave
# 1114       3                    air weave
# 1115       3                    air weave
# 1116       2           air weave showroom
# 1117       3         tuft needle referred
# 1118       6                     mattress
# 1119       6              buying mattress
# 1120       3                     brooklyn
# 1121       1             try tuten needle
# 1122       1       buy best hard mattress
# 1123       1              scosis mattress
# 1124       2                talalay latex
#
#                                 keywords_original
# 0                                 nectar  website
# 1                          nectar  mattress store
# 2                                          nectar
# 3                                  googled nectar
# 4                                nectar  showroom
# 5                                     nectar  try
# 6                                nectar  research
# 7                                nectar  mattress
# 8                             where to try nectar
# 9                 google - nectar  mattress store
# 10               online "nectar  distributor page
# 11                             nectar  mattresses
# 12                  nectar  brick and motar store
# 13                            online; nectar  try
# 14                          purple nectar  casper
# 15                                 nectar  stores
# 16                      google nectar  and purple
# 17                                nectar  matress
# 18                                    nectar  vs.
# 19                                  google nectar
# 20                              nectar  showrooms
# 21                      google nectar  to try out
# 22                           try nectar  mattress
# 23                               nectar  in store
# 24                                    nectar  nyc
# 25                              try casper nectar
# 26                                 nectar  ,ecosa
# 27                              nectar  bed in ny
# 28                                    nectar  bed
# 29                           nectar  mattress nyc
# ...                                           ...
# 1095                   google adjust able bed nyc
# 1096                 google:  purple mattress nyc
# 1097                     google:  purple mattress
# 1098                            google:  mattress
# 1099        google:  mattress showrooms manhattan
# 1100                         bear rep resentitive
# 1101                 casper store rep resentative
# 1102                                    leesa rep
# 1103                            consumer rep orts
# 1104                  casper store representative
# 1105                          mattress location s
# 1106  brooklyn bedding website link to our  store
# 1107                            air weave partner
# 1108                            air weave website
# 1109                        air weave dealer site
# 1110                               air weave firm
# 1111                                    air weave
# 1112                           air weave mattress
# 1113                   walk in, air weave website
# 1114                             online air weave
# 1115                            online air  weave
# 1116                           air weave showroom
# 1117                    tufts and needle referred
# 1118                  online mattress via  google
# 1119                    buying  online mattresses
# 1120                            brooklyn bedding1
# 1121                            try tuten  needle
# 1122         where to buy the best hard  mattress
# 1123                             scosis  mattress
# 1124                        google talalay  latex
#
# [1125 rows x 3 columns]

# %%
# save cluster result to excel file
# df_keyword_cluster.to_excel('cluster_result.xlsx')
